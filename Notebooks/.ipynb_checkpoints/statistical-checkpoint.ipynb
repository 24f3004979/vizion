# %% [markdown]
# # Statistical Approach
#
# AIM : Loading dataset with informative way to derive statistical thinking into the dataset core feature listing
# Core features
# 1. Visualizing trends of dataset with respect to anchor columns
# 2. Modeling Dataset with random variables
# 3. Studying RANDOM VARIABLE DISTRIBUTIONS
# 4. Expanding distribution fiting algorithm pathways
# 5. Expanding topic with statistical sample approached study about big dataset distribution prediction
#
# ### Motivation
# Studying about implementation constraints of statistical analysis and observing pattern for automating this whole pipeline into working module in VIZION
#
# **GOAL : Making automated statistical layer which automatically models dataset into probability model and attempts to find the underlying probability modeling for the dataset**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/madhav/workspace/Project/vizion/.venv/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/madhav/workspace/Project/vizion/.venv/lib/python3.12/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/madhav/workspace/Project/vizion/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/madhav/workspace/Project/vizion/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Dataset Screening for  analysis
# Critical Dataset Filter
# * Identifying non-required columns
#       + Basic Meta Dataset
#       + Additional Non variant information
# * Unique Identifying Information screening
#   Extracting information like customer id | unique identification units
#
# **Extracting all Dataset away which wont be usefull in further analysis**
# Unique Identification Order
# + Unique identification dataset | critical for distributing mass scale data insight tailoured towards one individual
# + Additional Filter chain
#       * Filteration information for chaining multiple detail layer
#       * Used into main DB-fetch for the dataset loading for tailoured dashboard api
#       * Filteration layer for filtering insights

# %%
import pandas as pd

df = pd.read_csv("data_customer.csv")
df.head()
# Out:
#   Customer_ID Region       Industry Lead_Source    Month  Marketing_Spend_USD  \
# 0    CUST1002  South     Healthcare      Events  2025-10                20937
# 1    CUST1003  South  Manufacturing       Email  2025-11                19988
# 2    CUST1004   East  Manufacturing    WhatsApp  2025-11                10002
# 3    CUST1005  North     Healthcare      Events  2025-08                26277
# 4    CUST1006   East         Retail    Referral  2025-10                 7348
#
#    Website_Visits  Product_Views  Past_Purchases  Avg_Order_Value  \
# 0            4731           1319              42           984.61
# 1            6397           1180               4           934.37
# 2            8515           4903              43           309.30
# 3            6581           3142               0           280.66
# 4            1743           1783               1            70.00
#
#    Customer_Satisfaction  Demand_Units  Competitor_Price_Index  \
# 0                   3.15           507                    0.90
# 1                   3.66           656                    0.95
# 2                   2.55           853                    0.89
# 3                   3.42           452                    1.02
# 4                   3.13           764                    0.97
#
#    Seasonality_Index  Forecast_Next_Month_Demand
# 0               0.94                         576
# 1               1.24                         829
# 2               1.26                        1305
# 3               1.26                         569
# 4               0.93                         714

# %%
# Sample Data visualization
import matplotlib.pyplot as plt

frame = df.groupby('Lead_Source').sum('Forest_Next_Month_Demand')

plt.plot(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Sample Data visualization
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 frame = df.groupby('Lead_Source').sum('Forest_Next_Month_Demand')
#       5
#       6 plt.plot(frame)
#
# File ~/workspace/Project/vizion/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:3065, in GroupBy.sum(self, numeric_only, min_count, skipna, engine, engine_kwargs)
#    3060 else:
#    3061     # If we are grouping on categoricals we want unobserved categories to
#    3062     # return zero, rather than the default of NaN which the reindexing in
#    3063     # _agg_general() returns. GH #31422
#    3064     with com.temp_setattr(self, "observed", True):
# -> 3065         result = self._agg_general(
#    3066             numeric_only=numeric_only,
#    3067             min_count=min_count,
#    3068             alias="sum",
#    3069             npfunc=np.sum,
#    3070             skipna=skipna,
#    3071         )
#    3073     return result
#
# File ~/workspace/Project/vizion/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1708, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1698 @final
#    1699 def _agg_general(
#    1700     self,
#    (...)   1706     **kwargs,
#    1707 ):
# -> 1708     result = self._cython_agg_general(
#    1709         how=alias,
#    1710         alt=npfunc,
#    1711         numeric_only=numeric_only,
#    1712         min_count=min_count,
#    1713         **kwargs,
#    1714     )
#    1715     return result.__finalize__(self.obj, method="groupby")
#
# File ~/workspace/Project/vizion/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1777, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1764 @final
#    1765 def _cython_agg_general(
#    1766     self,
#    (...)   1773     # Note: we never get here with how="ohlc" for DataFrameGroupBy;
#    1774     #  that goes through SeriesGroupBy
#    1776     if not is_bool(numeric_only):
# -> 1777         raise ValueError("numeric_only accepts only Boolean values")
#    1779     data = self._get_data_to_aggregate(numeric_only=numeric_only, name=how)
#    1781     def array_func(values: ArrayLike) -> ArrayLike:
#
# ValueError: numeric_only accepts only Boolean values
